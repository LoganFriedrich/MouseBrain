# %% [markdown]
# # Z-Score + Otsu Thresholding: How It Works
#
# **Purpose:** Manually rebuild the z-score + Otsu classification algorithm from scratch to understand every step.
#
# **What this mirrors in our codebase:**
# - Detection z-score: `mousebrain/plugin_2d/sliceatlas/core/detection.py` lines 263-279
# - Colocalization z-score + Otsu: `mousebrain/plugin_2d/sliceatlas/core/colocalization.py` lines 932-1005
#
# **This notebook is a learning tool only — not used in any pipeline.**

# %% [markdown]
# ---
# ## Section 1: Create Synthetic Fluorescence Data

# %% [markdown]
# ---
# ## Section 2: Why Mean/Std Fail (The Outlier Problem)

# %% [markdown]
# ---
# ## Section 3: Robust Background Estimation (Median + MAD)

# %% [markdown]
# ---
# ## Section 4: Compute Z-Scores

# %% [markdown]
# ---
# ## Section 5: Plain Otsu's Method (On Raw Intensities)

# %% [markdown]
# ---
# ## Section 6: Otsu on Z-Scores (The Combination)

# %% [markdown]
# ---
# ## Section 7: The Fallback — When Otsu Fails

# %% [markdown]
# ---
# ## Section 8: Full Pipeline + Visualizations
